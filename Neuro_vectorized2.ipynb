# %% [markdown]
# Vectorized implemementation

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import torchvision
import matplotlib.pyplot as plt
import random
from torchvision import datasets, transforms

# data1 = scipy.io.loadmat(r"JE1504_10u_r4c4_50_ohm_pot_dep_at_23-01-2024_17-39-54final_data_10.mat")
# data2 = scipy.io.loadmat(r"JE1504_10u_r4c4_50_ohm_pot_dep_at_23-01-2024_17-46-44final_data_10.mat")
# data3 = scipy.io.loadmat(r"JE1504_10u_r4c4_50_ohm_pot_dep_at_23-01-2024_17-53-02final_data_10.mat")
# data1 = data1['combined_data']
# data2 = data2['combined_data']
# data3 = data3['combined_data']
# # print the shape of the data

# # reduce dimensionality of the data
# data1 = np.squeeze(data1)
# data2 = np.squeeze(data2)
# data3 = np.squeeze(data3)

# plt.figure(figsize=(20, 10))
# plt.grid()
# plt.plot(data1)
# plt.show()

# # lengths of data1 2 and 3 are multiples of 20. So we can reshape them to 20xN
# data1 = data1.reshape(-1, 20)
# data2 = data2.reshape(-1, 20)
# data3 = data3.reshape(-1, 20)

# # concatenate the data1, data2 and data3
# data = np.concatenate((data1, data2, data3), axis=0)

# # plot all rows of concatenated data
# plt.figure(figsize=(20, 10))
# plt.grid()
# for i in range(data.shape[0]):
#     plt.plot(data[i])
# plt.show()

# scaled_data = (data - 0.000256) / (0.000302 - 0.000256)
# scaled_data = scaled_data

# %%
class Device_Idealized_Matrix:
    def __init__(self, num_rows, num_cols):
        self.noise = 0.1
        self.increment_scale_factor = 0.25
        self.decrement_scale_factor = 0.25
        self.device2device_variability_conductance_variation = 0
        self.cycle2cycle_variability_conductance_variation = 0.1
        self.average_max_conductance = 1
        self.average_min_conductance = -1
        self.device_weights = (self.average_max_conductance - self.average_min_conductance)*np.random.rand(num_rows, num_cols) + self.average_min_conductance

    def increment(self, increment_indexes):
        # increment_indexes contains the indexes of the devices to be incremented, 1 for increment, 0 for no change
        self.device_weights += increment_indexes*(self.average_max_conductance - self.device_weights) * self.increment_scale_factor * (1 + np.random.uniform(-self.noise, self.noise))

    def decrement(self, decrement_indexes):
        # decrement_indexes contains the indexes of the devices to be decremented, 1 for decrement, 0 for no change
        self.device_weights -= decrement_indexes*(self.device_weights - self.average_min_conductance)* self.decrement_scale_factor * (1 + np.random.uniform(-self.noise, self.noise))

    def read_weights(self):
        return self.device_weights

    def reset(self, reset_indexes):
        # reset_indexes, a matrix of num_rows and num_cols contains the indexes of the devices to be reset, 1 for reset, 0 for no change
        # create a numpy array of the same shape as device_weights
        self.device_weights_new = self.average_min_conductance + np.random.uniform(-self.cycle2cycle_variability_conductance_variation, self.cycle2cycle_variability_conductance_variation, self.device_weights.shape)
        self.device_weights = np.where(reset_indexes == 1, self.device_weights_new, self.device_weights)

    def set(self, set_indexes):
        # set_indexes, a matrix of num_rows and num_cols contains the indexes of the devices to be set, 1 for set, 0 for no change
        self.device_weights_new = self.average_max_conductance + np.random.uniform(-self.cycle2cycle_variability_conductance_variation, self.cycle2cycle_variability_conductance_variation, self.device_weights.shape)
        self.device_weights = np.where(set_indexes == 1, self.device_weights_new, self.device_weights)

# %%
# simulate 12 incremental steps and 12 decremental steps
num_rows = 1
num_cols = 1
device = Device_Idealized_Matrix(num_rows, num_cols)

weight_list = []
weight_list.append(device.read_weights()[0][0])
for i in range(12):
    increment_indexes = np.asarray([[1]])
    device.increment(increment_indexes)
    weight_list.append(device.read_weights()[0][0])

for i in range(12):
    decrement_indexes = np.asarray([[1]])
    device.decrement(decrement_indexes)
    weight_list.append(device.read_weights()[0][0])

plt.figure(figsize=(20, 10))
plt.grid()
plt.plot(weight_list, marker='o')
plt.show()

# %%
class Composite_Device_Idealized_Matrix:
    def __init__(self, num_rows, num_cols, scaling_weights):
        # sort scaling weights in ascending order
        scaling_weights = np.sort(scaling_weights)
        self.scaling_weights = scaling_weights
        self.num_rows = num_rows
        self.num_cols = num_cols
        self.len_scaling_weights = len(scaling_weights)
        self.device_arrays = [Device_Idealized_Matrix(num_rows, num_cols) for i in range(self.len_scaling_weights)]
        self.cutoff_zone_d = 0.80
        self.cutoff_zone_p = -0.80

        # total weight = weighted sum of all the device_weight arrays
        self.total_weight = np.zeros((num_rows, num_cols), dtype=np.float32)

        for i in range(self.len_scaling_weights):
            self.total_weight += self.scaling_weights[i]*self.device_arrays[i].read_weights()

    def increment(self, increment_indexes):

        # layer_1_indices = np.where(self.device_arrays[0].read_weights() < self.cutoff_zone_d)
        # self.device_arrays[0].increment(increment_indexes=layer_1_indices)

        and_array = np.ones((self.num_rows, self.num_cols), dtype=bool)

        # AND between and array and increment indexes
        and_array = np.logical_and(and_array, increment_indexes)

        or_array = np.zeros((self.num_rows, self.num_cols), dtype=bool)
        reset_list = []
        # # change datatype of and array to boolean
        # and_array = and_array.astype(bool)

        for i in range(self.len_scaling_weights):
            # print("Device array: ", i)
            out_of_zone_d_indices = self.device_arrays[i].read_weights() > self.cutoff_zone_d
            # print("Out of zone d indices: ", out_of_zone_d_indices)

            # increment indexes = XOR between and_array and out_of_zone_d_indices
            increment_indexes = np.logical_xor(and_array, out_of_zone_d_indices)
            # print("Increment indexes: ", increment_indexes)

            # make increment_indexes 0 where or_array is 1
            increment_indexes = np.where(or_array == 1, 0, increment_indexes)
            # print("Increment indexes after or_array: ", increment_indexes)

            # increment the devices
            self.device_arrays[i].increment(increment_indexes)


            # OR between or_array and increment_indexes
            or_array = np.logical_or(or_array, increment_indexes)
            # print("Or array: ", or_array)

            # AND between and_array and out_of_zone_d_indices
            and_array = np.logical_and(and_array, out_of_zone_d_indices)
            # print("And array: ", and_array)

            reset_list.append(and_array)

        # for i in range(self.len_scaling_weights - 1):
        #     reset_indices = np.where(reset_list[-1] == 1, 0, reset_list[i])
        #     self.device_arrays[i].reset(reset_indices)

    def decrement(self, decrement_indexes):

            and_array = np.ones((self.num_rows, self.num_cols), dtype=bool)
            or_array = np.zeros((self.num_rows, self.num_cols), dtype=bool)

            # AND between and array and decrement indexes
            and_array = np.logical_and(and_array, decrement_indexes)
            # # change datatype of and array to boolean
            # and_array = and_array.astype(bool)
            set_list = []

            for i in range(self.len_scaling_weights):
                out_of_zone_p_indices = self.device_arrays[i].read_weights() < self.cutoff_zone_p

                # decrement indexes = XOR between and_array and out_of_zone_d_indices
                decrement_indexes = np.logical_xor(and_array, out_of_zone_p_indices)

                # make decrement_indexes 0 where or_array is 1
                decrement_indexes = np.where(or_array == 1, 0, decrement_indexes)

                # decrement the devices
                self.device_arrays[i].decrement(decrement_indexes)

                # OR between or_array and decrement_indexes
                or_array = np.logical_or(or_array, decrement_indexes)

                # AND between and_array and out_of_zone_d_indices
                and_array = np.logical_and(and_array, out_of_zone_p_indices)

                set_list.append(and_array)

            # for i in range(self.len_scaling_weights - 1):
            #     set_indices = np.where(set_list[-1] == 1, 0, set_list[i])
            #     self.device_arrays[i].set(set_indices)

    def read_weights(self):
        self.total_weight = np.zeros((self.num_rows, self.num_cols), dtype=np.float32)
        for i in range(self.len_scaling_weights):
            self.total_weight += self.scaling_weights[i]*self.device_arrays[i].read_weights()
        return self.total_weight

# %%
# Simulate a neuron by num_rows = 1, num_columns = 1

# create a composite device with 1 row and 1 column
composite_device = Composite_Device_Idealized_Matrix(num_rows=1, num_cols=1, scaling_weights=[0.1 for i in range (3)])

# read the weights of the composite device
# print(composite_device.read_weights()[0][0])

weight_list = []

weight_list.append(composite_device.read_weights()[0][0])

increment_indexes = np.ones((1,1))

# increment the weights of the composite device
for i in range(1225):
    # print("Increment ", i)
    composite_device.increment(increment_indexes=increment_indexes)
    weight_list.append(composite_device.read_weights()[0][0])


# decrement the weights of the composite device
for i in range(205):
    composite_device.decrement(decrement_indexes=increment_indexes)
    weight_list.append(composite_device.read_weights()[0][0])


for i in range(250):
    # print("Increment ", i)
    composite_device.increment(increment_indexes=increment_indexes)
    weight_list.append(composite_device.read_weights()[0][0])

plt.figure(figsize=(20, 10))
plt.grid()
plt.plot(weight_list, marker='o')
plt.show()

# %%
class MyModel(nn.Module):
    def __init__(self):
        super(MyModel, self).__init__()
        self.fc1 = nn.Linear(784, 250, bias = False)
        self.fc2 = nn.Linear(250, 10, bias = False)

    def forward(self, x):
        x1 = F.sigmoid(self.fc1(x))
        x2 = self.fc2(x1)
        return x2

# Initialize the model
model = MyModel()
# Define the loss function
loss_fn = nn.CrossEntropyLoss()
# loss_fn = nn.MSELoss()
# loss_fn = nn.MSELoss

# Define the optimizer
optimizer = optim.SGD(model.parameters(), lr=0.1)
print(model)
# Out:
# MyModel(
#   (fc1): Linear(in_features=784, out_features=250, bias=False)
#   (fc2): Linear(in_features=250, out_features=10, bias=False)
# )

# %%
from torchvision import datasets, transforms
transform = transforms.Compose([transforms.ToTensor(),
                              transforms.Normalize((0.5,), (0.5,)),
                              ])
# transform = transforms.Compose([transforms.ToTensor()])

import torch
from torch.utils.data import DataLoader, SubsetRandomSampler
from torchvision import datasets, transforms

# Define the transformation to convert data to tensors
transform = transforms.ToTensor()

# Load the MNIST dataset
full_train_dataset = datasets.MNIST(root="data", train=True, download=True, transform=transform)
full_test_dataset = datasets.MNIST(root="data", train=False, download=True, transform=transform)


train_loader = DataLoader(full_train_dataset, batch_size=64, shuffle=True)

test_loader = DataLoader(full_test_dataset, batch_size=64, shuffle=True)

# %%
layer_wise_composite_device_array = []
# each layer can be represented by one matrix of appropriate rows and columns

# Calculate number of layers in our model
num_layers = 2

input_sizes = [784, 250]
output_sizes = [250, 10]

for i in range(num_layers):
    layer_wise_composite_device_array.append(Composite_Device_Idealized_Matrix(num_rows=output_sizes[i], num_cols=input_sizes[i], scaling_weights=[0.01,0.1,1]))

# %%
import torch
if torch.cuda.is_available():
    device_name = torch.device("cuda")
else:
    device_name = torch.device('cpu')

print(device_name)
# Out:
# cpu

# %%
# First, assign the corresponding device weight to the model
# Calculate the new weights
new_weights_1 = layer_wise_composite_device_array[0].read_weights()
new_weights_2 = layer_wise_composite_device_array[1].read_weights()

buffer = new_weights_1*1

# Assign the new weights to the model
model.fc1.weight.data = torch.from_numpy(new_weights_1)
model.fc2.weight.data = torch.from_numpy(new_weights_2)

num_epochs = 1
num_steps_per_batch = 1

weight_evolution_list_1 = []
weight_evolution_list_2 = []
weight_evolution_list_3 = []
weight_evolution_list_4 = []
weight_evolution_list_5 = []
# The training loop

for epoch in range(num_epochs):
    batch_number = 0
    for batch, (images, labels) in enumerate(train_loader):
        batch_number += 1
        for step in range(num_steps_per_batch):
            images2 = images.view(images.shape[0], -1)
            # print(images.shape)
            # Forward pass
            output = model(images2)
            # print(output.shape)
            # Calculate the loss
            loss = loss_fn(output, labels)
            # print(output)
            # print(labels)
            # print(loss)
            # Zero the gradients
            optimizer.zero_grad()
            # Backward pass
            loss.backward()

            # Extract weights in numpy 2d arrays
            weights_1 = model.fc1.weight.data.numpy()
            weights_2 = model.fc2.weight.data.numpy()

            # Extract the gradients in numpy 2d arrays
            grad_1 = model.fc1.weight.grad.numpy()
            grad_2 = model.fc2.weight.grad.numpy()

            # For layer 1
            layer_wise_composite_device_array[0].increment(increment_indexes = (grad_1 < 0))
            layer_wise_composite_device_array[0].decrement(decrement_indexes = (grad_1 > 0))

            # For layer 2
            layer_wise_composite_device_array[1].increment(increment_indexes = (grad_2 < 0))
            layer_wise_composite_device_array[1].decrement(decrement_indexes = (grad_2 > 0))

            # Calculate the new weights
            new_weights_1 = layer_wise_composite_device_array[0].read_weights()
            new_weights_2 = layer_wise_composite_device_array[1].read_weights()

            weight_evolution_list_1.append(new_weights_1[0][0])
            weight_evolution_list_2.append(new_weights_1[20][100])
            weight_evolution_list_3.append(new_weights_1[7][7])
            weight_evolution_list_4.append(new_weights_2[0][0])
            weight_evolution_list_5.append(new_weights_2[2][10])

            # Assign the new weights to the model
            model.fc1.weight.data = torch.from_numpy(new_weights_1)
            model.fc2.weight.data = torch.from_numpy(new_weights_2)

        # Print the loss
        print('Batch Number {}, Loss: {:.4f}'.format(batch_number, loss.item()))
# Out:
# Batch Number 1, Loss: 9.0060
# Batch Number 2, Loss: 7.1063
# Batch Number 3, Loss: 5.4589
# Batch Number 4, Loss: 4.7623
# Batch Number 5, Loss: 3.8240
# Batch Number 6, Loss: 3.3016
# Batch Number 7, Loss: 3.3965
# Batch Number 8, Loss: 2.4805
# Batch Number 9, Loss: 2.1454
# Batch Number 10, Loss: 2.2109
# Batch Number 11, Loss: 1.8543
# Batch Number 12, Loss: 1.4408
# Batch Number 13, Loss: 1.4930
# Batch Number 14, Loss: 1.4933
# Batch Number 15, Loss: 0.7841
# Batch Number 16, Loss: 1.2998
# Batch Number 17, Loss: 0.9242
# Batch Number 18, Loss: 0.7980
# Batch Number 19, Loss: 0.6127
# Batch Number 20, Loss: 1.1479
# Batch Number 21, Loss: 0.8885
# Batch Number 22, Loss: 1.0547
# Batch Number 23, Loss: 0.5393
# Batch Number 24, Loss: 1.4155
# Batch Number 25, Loss: 0.5944
# Batch Number 26, Loss: 1.1498
# Batch Number 27, Loss: 0.9410
# Batch Number 28, Loss: 1.2076
# Batch Number 29, Loss: 0.8017
# Batch Number 30, Loss: 0.4501
# Batch Number 31, Loss: 1.1187
# Batch Number 32, Loss: 0.6825
# Batch Number 33, Loss: 0.5410
# Batch Number 34, Loss: 1.2863
# Batch Number 35, Loss: 0.6184
# Batch Number 36, Loss: 0.6207
# Batch Number 37, Loss: 0.6997
# Batch Number 38, Loss: 1.2432
# Batch Number 39, Loss: 0.5661
# Batch Number 40, Loss: 0.7428
# Batch Number 41, Loss: 0.7847
# Batch Number 42, Loss: 0.8879
# Batch Number 43, Loss: 0.7471
# Batch Number 44, Loss: 0.5111
# Batch Number 45, Loss: 0.3720
# Batch Number 46, Loss: 0.5516
# Batch Number 47, Loss: 0.7126
# Batch Number 48, Loss: 0.7014
# Batch Number 49, Loss: 0.5524
# Batch Number 50, Loss: 0.7077
# Batch Number 51, Loss: 0.6009
# Batch Number 52, Loss: 0.7773
# Batch Number 53, Loss: 0.6843
# Batch Number 54, Loss: 0.6841
# Batch Number 55, Loss: 0.3776
# Batch Number 56, Loss: 0.9635
# Batch Number 57, Loss: 0.4777
# Batch Number 58, Loss: 0.9115
# Batch Number 59, Loss: 0.3981
# Batch Number 60, Loss: 0.5415
# Batch Number 61, Loss: 0.7210
# Batch Number 62, Loss: 0.5020
# Batch Number 63, Loss: 0.9374
# Batch Number 64, Loss: 0.7034
# Batch Number 65, Loss: 0.9184
# Batch Number 66, Loss: 0.7146
# Batch Number 67, Loss: 0.5028
# Batch Number 68, Loss: 0.7030
# Batch Number 69, Loss: 0.6378
# Batch Number 70, Loss: 0.7480
# Batch Number 71, Loss: 0.4747
# Batch Number 72, Loss: 0.6137
# Batch Number 73, Loss: 0.3715
# Batch Number 74, Loss: 0.7894
# Batch Number 75, Loss: 0.6275
# Batch Number 76, Loss: 0.4171
# Batch Number 77, Loss: 1.7925
# Batch Number 78, Loss: 0.4282
# Batch Number 79, Loss: 0.9080
# Batch Number 80, Loss: 0.3451
# Batch Number 81, Loss: 0.7084
# Batch Number 82, Loss: 0.7200
# Batch Number 83, Loss: 0.2974
# Batch Number 84, Loss: 0.3957
# Batch Number 85, Loss: 0.3413
# Batch Number 86, Loss: 0.9311
# Batch Number 87, Loss: 0.8603
# Batch Number 88, Loss: 0.4111
# Batch Number 89, Loss: 0.8977
# Batch Number 90, Loss: 0.4602
# Batch Number 91, Loss: 0.4603
# Batch Number 92, Loss: 0.3380
# Batch Number 93, Loss: 0.6691
# Batch Number 94, Loss: 0.2986
# Batch Number 95, Loss: 0.5594
# Batch Number 96, Loss: 0.3729
# Batch Number 97, Loss: 0.2893
# Batch Number 98, Loss: 0.4359
# Batch Number 99, Loss: 0.5748
# Batch Number 100, Loss: 0.1905
# Batch Number 101, Loss: 0.3425
# Batch Number 102, Loss: 0.2305
# Batch Number 103, Loss: 0.7407
# Batch Number 104, Loss: 0.2467
# Batch Number 105, Loss: 0.6690
# Batch Number 106, Loss: 0.5673
# Batch Number 107, Loss: 0.7448
# Batch Number 108, Loss: 0.6639
# Batch Number 109, Loss: 0.5012
# Batch Number 110, Loss: 0.3383
# Batch Number 111, Loss: 0.3893
# Batch Number 112, Loss: 0.3957
# Batch Number 113, Loss: 0.5515
# Batch Number 114, Loss: 0.3877
# Batch Number 115, Loss: 0.8537
# Batch Number 116, Loss: 0.3606
# Batch Number 117, Loss: 0.5746
# Batch Number 118, Loss: 0.5065
# Batch Number 119, Loss: 0.5535
# Batch Number 120, Loss: 0.9892
# Batch Number 121, Loss: 0.6833
# Batch Number 122, Loss: 0.5094
# Batch Number 123, Loss: 0.3935
# Batch Number 124, Loss: 0.1442
# Batch Number 125, Loss: 0.2995
# Batch Number 126, Loss: 0.5392
# Batch Number 127, Loss: 0.3497
# Batch Number 128, Loss: 0.4180
# Batch Number 129, Loss: 0.2400
# Batch Number 130, Loss: 0.4342
# Batch Number 131, Loss: 0.5694
# Batch Number 132, Loss: 0.6148
# Batch Number 133, Loss: 0.2718
# Batch Number 134, Loss: 0.5510
# Batch Number 135, Loss: 0.4037
# Batch Number 136, Loss: 0.3291
# Batch Number 137, Loss: 0.5078
# Batch Number 138, Loss: 0.2506
# Batch Number 139, Loss: 0.8398
# Batch Number 140, Loss: 0.2758
# Batch Number 141, Loss: 0.3984
# Batch Number 142, Loss: 0.0901
# Batch Number 143, Loss: 0.4803
# Batch Number 144, Loss: 0.3975
# Batch Number 145, Loss: 0.6584
# Batch Number 146, Loss: 0.5724
# Batch Number 147, Loss: 0.8497
# Batch Number 148, Loss: 0.4426
# Batch Number 149, Loss: 0.5662
# Batch Number 150, Loss: 0.6095
# Batch Number 151, Loss: 0.9236
# Batch Number 152, Loss: 0.5019
# Batch Number 153, Loss: 0.5458
# Batch Number 154, Loss: 0.6300
# Batch Number 155, Loss: 0.3853
# Batch Number 156, Loss: 0.2580
# Batch Number 157, Loss: 0.7260
# Batch Number 158, Loss: 0.6276
# Batch Number 159, Loss: 0.2445
# Batch Number 160, Loss: 0.4119
# Batch Number 161, Loss: 0.8425
# Batch Number 162, Loss: 0.5449
# Batch Number 163, Loss: 0.5904
# Batch Number 164, Loss: 0.8911
# Batch Number 165, Loss: 0.5053
# Batch Number 166, Loss: 1.1948
# Batch Number 167, Loss: 0.5096
# Batch Number 168, Loss: 0.8586
# Batch Number 169, Loss: 0.2257
# Batch Number 170, Loss: 0.7494
# Batch Number 171, Loss: 0.5996
# Batch Number 172, Loss: 0.1526
# Batch Number 173, Loss: 0.6863
# Batch Number 174, Loss: 0.5080
# Batch Number 175, Loss: 0.5529
# Batch Number 176, Loss: 0.6729
# Batch Number 177, Loss: 0.1785
# Batch Number 178, Loss: 0.1933
# Batch Number 179, Loss: 0.5991
# Batch Number 180, Loss: 0.6266
# Batch Number 181, Loss: 0.8491
# Batch Number 182, Loss: 0.3956
# Batch Number 183, Loss: 0.8645
# Batch Number 184, Loss: 0.9627
# Batch Number 185, Loss: 0.9105
# Batch Number 186, Loss: 0.4966
# Batch Number 187, Loss: 0.7501
# Batch Number 188, Loss: 0.5873
# Batch Number 189, Loss: 0.2712
# Batch Number 190, Loss: 0.3565
# Batch Number 191, Loss: 0.4496
# Batch Number 192, Loss: 0.3078
# Batch Number 193, Loss: 0.6021
# Batch Number 194, Loss: 0.5567
# Batch Number 195, Loss: 0.5411
# Batch Number 196, Loss: 0.9508
# Batch Number 197, Loss: 0.5519
# Batch Number 198, Loss: 1.0663
# Batch Number 199, Loss: 0.2270
# Batch Number 200, Loss: 0.2134
# Batch Number 201, Loss: 0.3373
# Batch Number 202, Loss: 0.0375
# Batch Number 203, Loss: 0.6601
# Batch Number 204, Loss: 0.4830
# Batch Number 205, Loss: 0.8121
# Batch Number 206, Loss: 0.1676
# Batch Number 207, Loss: 0.4700
# Batch Number 208, Loss: 0.5818
# Batch Number 209, Loss: 0.2101
# Batch Number 210, Loss: 0.2934
# Batch Number 211, Loss: 0.6147
# Batch Number 212, Loss: 0.6289
# Batch Number 213, Loss: 0.4639
# Batch Number 214, Loss: 0.5915
# Batch Number 215, Loss: 0.7008
# Batch Number 216, Loss: 0.7178
# Batch Number 217, Loss: 0.6952
# Batch Number 218, Loss: 0.3010
# Batch Number 219, Loss: 0.4502
# Batch Number 220, Loss: 0.6008
# Batch Number 221, Loss: 0.4181
# Batch Number 222, Loss: 0.8142
# Batch Number 223, Loss: 1.1597
# Batch Number 224, Loss: 0.3909
# Batch Number 225, Loss: 0.4265
# Batch Number 226, Loss: 0.1745
# Batch Number 227, Loss: 0.7443
# Batch Number 228, Loss: 0.3192
# Batch Number 229, Loss: 0.3082
# Batch Number 230, Loss: 0.1347
# Batch Number 231, Loss: 0.6134
# Batch Number 232, Loss: 0.5136
# Batch Number 233, Loss: 0.8130
# Batch Number 234, Loss: 0.2510
# Batch Number 235, Loss: 0.3335
# Batch Number 236, Loss: 0.4062
# Batch Number 237, Loss: 0.4169
# Batch Number 238, Loss: 0.3538
# Batch Number 239, Loss: 0.4996
# Batch Number 240, Loss: 0.3288
# Batch Number 241, Loss: 0.3350
# Batch Number 242, Loss: 0.1289
# Batch Number 243, Loss: 0.8574
# Batch Number 244, Loss: 0.3322
# Batch Number 245, Loss: 1.0283
# Batch Number 246, Loss: 0.5160
# Batch Number 247, Loss: 0.5103
# Batch Number 248, Loss: 0.2417
# Batch Number 249, Loss: 0.8818
# Batch Number 250, Loss: 0.2683
# Batch Number 251, Loss: 0.7037
# Batch Number 252, Loss: 0.3698
# Batch Number 253, Loss: 0.6917
# Batch Number 254, Loss: 0.2871
# Batch Number 255, Loss: 0.3348
# Batch Number 256, Loss: 0.7409
# Batch Number 257, Loss: 0.4294
# Batch Number 258, Loss: 0.7308
# Batch Number 259, Loss: 0.2134
# Batch Number 260, Loss: 0.6840
# Batch Number 261, Loss: 0.6191
# Batch Number 262, Loss: 0.6432
# Batch Number 263, Loss: 0.4689
# Batch Number 264, Loss: 0.7892
# Batch Number 265, Loss: 0.3237
# Batch Number 266, Loss: 0.6024
# Batch Number 267, Loss: 0.6098
# Batch Number 268, Loss: 0.6017
# Batch Number 269, Loss: 0.4471
# Batch Number 270, Loss: 0.8015
# Batch Number 271, Loss: 0.1076
# Batch Number 272, Loss: 0.4182
# Batch Number 273, Loss: 0.4682
# Batch Number 274, Loss: 0.3011
# Batch Number 275, Loss: 0.5928
# Batch Number 276, Loss: 0.5451
# Batch Number 277, Loss: 0.4268
# Batch Number 278, Loss: 0.4739
# Batch Number 279, Loss: 0.0796
# Batch Number 280, Loss: 0.9008
# Batch Number 281, Loss: 0.5874
# Batch Number 282, Loss: 0.5712
# Batch Number 283, Loss: 0.3653
# Batch Number 284, Loss: 0.5968
# Batch Number 285, Loss: 0.4045
# Batch Number 286, Loss: 0.4500
# Batch Number 287, Loss: 0.4617
# Batch Number 288, Loss: 0.3554
# Batch Number 289, Loss: 0.5270
# Batch Number 290, Loss: 0.7310
# Batch Number 291, Loss: 0.7528
# Batch Number 292, Loss: 0.7860
# Batch Number 293, Loss: 0.5443
# Batch Number 294, Loss: 0.2246
# Batch Number 295, Loss: 0.0759
# Batch Number 296, Loss: 0.3063
# Batch Number 297, Loss: 1.1605
# Batch Number 298, Loss: 0.3858
# Batch Number 299, Loss: 0.7350
# Batch Number 300, Loss: 0.4158
# Batch Number 301, Loss: 0.2545
# Batch Number 302, Loss: 0.2435
# Batch Number 303, Loss: 0.3386
# Batch Number 304, Loss: 0.6446
# Batch Number 305, Loss: 0.5060
# Batch Number 306, Loss: 0.6821
# Batch Number 307, Loss: 0.1381
# Batch Number 308, Loss: 0.5257
# Batch Number 309, Loss: 0.5923
# Batch Number 310, Loss: 0.5278
# Batch Number 311, Loss: 0.3446
# Batch Number 312, Loss: 0.4592
# Batch Number 313, Loss: 0.2457
# Batch Number 314, Loss: 1.5793
# Batch Number 315, Loss: 0.3292
# Batch Number 316, Loss: 0.2726
# Batch Number 317, Loss: 0.3893
# Batch Number 318, Loss: 0.6785
# Batch Number 319, Loss: 0.1774
# Batch Number 320, Loss: 0.7894
# Batch Number 321, Loss: 0.1323
# Batch Number 322, Loss: 1.0363
# Batch Number 323, Loss: 1.0249
# Batch Number 324, Loss: 0.4497
# Batch Number 325, Loss: 0.8621
# Batch Number 326, Loss: 0.7314
# Batch Number 327, Loss: 0.2153
# Batch Number 328, Loss: 0.1699
# Batch Number 329, Loss: 0.5441
# Batch Number 330, Loss: 0.7729
# Batch Number 331, Loss: 0.2450
# Batch Number 332, Loss: 0.4182
# Batch Number 333, Loss: 0.1128
# Batch Number 334, Loss: 0.2911
# Batch Number 335, Loss: 0.3115
# Batch Number 336, Loss: 0.4156
# Batch Number 337, Loss: 0.4126
# Batch Number 338, Loss: 0.8394
# Batch Number 339, Loss: 0.4140
# Batch Number 340, Loss: 1.0365
# Batch Number 341, Loss: 0.6852
# Batch Number 342, Loss: 0.5271
# Batch Number 343, Loss: 0.5894
# Batch Number 344, Loss: 0.3769
# Batch Number 345, Loss: 0.8543
# Batch Number 346, Loss: 0.3800
# Batch Number 347, Loss: 0.5573
# Batch Number 348, Loss: 0.3188
# Batch Number 349, Loss: 0.3313
# Batch Number 350, Loss: 0.1658
# Batch Number 351, Loss: 0.6419
# Batch Number 352, Loss: 0.3252
# Batch Number 353, Loss: 0.3892
# Batch Number 354, Loss: 0.2230
# Batch Number 355, Loss: 0.3643
# Batch Number 356, Loss: 0.3638
# Batch Number 357, Loss: 0.1893
# Batch Number 358, Loss: 0.4000
# Batch Number 359, Loss: 0.7148
# Batch Number 360, Loss: 0.3920
# Batch Number 361, Loss: 0.7132
# Batch Number 362, Loss: 0.3096
# Batch Number 363, Loss: 0.3246
# Batch Number 364, Loss: 0.1885
# Batch Number 365, Loss: 0.8427
# Batch Number 366, Loss: 0.3307
# Batch Number 367, Loss: 0.8538
# Batch Number 368, Loss: 0.3258
# Batch Number 369, Loss: 0.5484
# Batch Number 370, Loss: 0.7173
# Batch Number 371, Loss: 0.8032
# Batch Number 372, Loss: 0.4438
# Batch Number 373, Loss: 0.4084
# Batch Number 374, Loss: 0.5248
# Batch Number 375, Loss: 0.2347
# Batch Number 376, Loss: 0.4890
# Batch Number 377, Loss: 0.2503
# Batch Number 378, Loss: 0.1405
# Batch Number 379, Loss: 0.5097
# Batch Number 380, Loss: 0.2595
# Batch Number 381, Loss: 0.2988
# Batch Number 382, Loss: 0.2530
# Batch Number 383, Loss: 0.1913
# Batch Number 384, Loss: 0.5605
# Batch Number 385, Loss: 1.2268
# Batch Number 386, Loss: 0.4000
# Batch Number 387, Loss: 0.3585
# Batch Number 388, Loss: 0.3932
# Batch Number 389, Loss: 0.8168
# Batch Number 390, Loss: 0.3439
# Batch Number 391, Loss: 0.3692
# Batch Number 392, Loss: 0.2058
# Batch Number 393, Loss: 0.3964
# Batch Number 394, Loss: 0.2985
# Batch Number 395, Loss: 0.5936
# Batch Number 396, Loss: 0.5371
# Batch Number 397, Loss: 0.1845
# Batch Number 398, Loss: 0.3486
# Batch Number 399, Loss: 0.3374
# Batch Number 400, Loss: 0.3474
# Batch Number 401, Loss: 0.4598
# Batch Number 402, Loss: 0.6108
# Batch Number 403, Loss: 0.3163
# Batch Number 404, Loss: 0.2653
# Batch Number 405, Loss: 0.1901
# Batch Number 406, Loss: 0.2136
# Batch Number 407, Loss: 0.3452
# Batch Number 408, Loss: 0.3019
# Batch Number 409, Loss: 0.2347
# Batch Number 410, Loss: 0.2200
# Batch Number 411, Loss: 0.5259
# Batch Number 412, Loss: 0.3043
# Batch Number 413, Loss: 0.8223
# Batch Number 414, Loss: 0.3100
# Batch Number 415, Loss: 0.2525
# Batch Number 416, Loss: 0.4058
# Batch Number 417, Loss: 0.5943
# Batch Number 418, Loss: 0.1808
# Batch Number 419, Loss: 0.4314
# Batch Number 420, Loss: 0.2913
# Batch Number 421, Loss: 0.2467
# Batch Number 422, Loss: 0.8048
# Batch Number 423, Loss: 0.5592
# Batch Number 424, Loss: 0.1840
# Batch Number 425, Loss: 0.6311
# Batch Number 426, Loss: 0.3481
# Batch Number 427, Loss: 0.2399
# Batch Number 428, Loss: 0.1357
# Batch Number 429, Loss: 0.2501
# Batch Number 430, Loss: 0.2583
# Batch Number 431, Loss: 0.5262
# Batch Number 432, Loss: 0.1261
# Batch Number 433, Loss: 0.2903
# Batch Number 434, Loss: 0.2829
# Batch Number 435, Loss: 0.5196
# Batch Number 436, Loss: 0.2185
# Batch Number 437, Loss: 0.1537
# Batch Number 438, Loss: 0.5903
# Batch Number 439, Loss: 0.4000
# Batch Number 440, Loss: 0.2311
# Batch Number 441, Loss: 0.3195
# Batch Number 442, Loss: 0.5005
# Batch Number 443, Loss: 0.5525
# Batch Number 444, Loss: 0.4219
# Batch Number 445, Loss: 0.4677
# Batch Number 446, Loss: 0.5172
# Batch Number 447, Loss: 0.3950
# Batch Number 448, Loss: 0.3958
# Batch Number 449, Loss: 0.3907
# Batch Number 450, Loss: 0.1747
# Batch Number 451, Loss: 0.5713
# Batch Number 452, Loss: 0.4193
# Batch Number 453, Loss: 0.2952
# Batch Number 454, Loss: 0.3535
# Batch Number 455, Loss: 0.3951
# Batch Number 456, Loss: 0.0956
# Batch Number 457, Loss: 0.1177
# Batch Number 458, Loss: 0.1058
# Batch Number 459, Loss: 0.3973
# Batch Number 460, Loss: 0.3053
# Batch Number 461, Loss: 0.3353
# Batch Number 462, Loss: 0.8431
# Batch Number 463, Loss: 0.7342
# Batch Number 464, Loss: 0.4589
# Batch Number 465, Loss: 0.6365
# Batch Number 466, Loss: 0.9366
# Batch Number 467, Loss: 0.2439
# Batch Number 468, Loss: 0.2910
# Batch Number 469, Loss: 0.4331
# Batch Number 470, Loss: 0.2104
# Batch Number 471, Loss: 0.0720
# Batch Number 472, Loss: 0.4606
# Batch Number 473, Loss: 0.3340
# Batch Number 474, Loss: 0.5211
# Batch Number 475, Loss: 0.5157
# Batch Number 476, Loss: 0.1775
# Batch Number 477, Loss: 0.2739
# Batch Number 478, Loss: 0.2769
# Batch Number 479, Loss: 0.4891
# Batch Number 480, Loss: 0.8430
# Batch Number 481, Loss: 0.2638
# Batch Number 482, Loss: 1.0234
# Batch Number 483, Loss: 0.9197
# Batch Number 484, Loss: 0.6478
# Batch Number 485, Loss: 0.5875
# Batch Number 486, Loss: 0.1943
# Batch Number 487, Loss: 0.3769
# Batch Number 488, Loss: 0.3165
# Batch Number 489, Loss: 0.6025
# Batch Number 490, Loss: 0.6463
# Batch Number 491, Loss: 0.3448
# Batch Number 492, Loss: 0.4032
# Batch Number 493, Loss: 0.0078
# Batch Number 494, Loss: 0.2773
# Batch Number 495, Loss: 0.3711
# Batch Number 496, Loss: 0.2203
# Batch Number 497, Loss: 0.0887
# Batch Number 498, Loss: 0.4549
# Batch Number 499, Loss: 0.1481
# Batch Number 500, Loss: 0.5261
# Batch Number 501, Loss: 0.1956
# Batch Number 502, Loss: 0.6870
# Batch Number 503, Loss: 0.3905
# Batch Number 504, Loss: 0.1943
# Batch Number 505, Loss: 0.4381
# Batch Number 506, Loss: 0.2953
# Batch Number 507, Loss: 0.4321
# Batch Number 508, Loss: 0.3145
# Batch Number 509, Loss: 0.4185
# Batch Number 510, Loss: 0.9067
# Batch Number 511, Loss: 0.2189
# Batch Number 512, Loss: 0.4588
# Batch Number 513, Loss: 0.8219
# Batch Number 514, Loss: 0.3939
# Batch Number 515, Loss: 0.3403
# Batch Number 516, Loss: 0.3206
# Batch Number 517, Loss: 0.8190
# Batch Number 518, Loss: 0.4891
# Batch Number 519, Loss: 0.5617
# Batch Number 520, Loss: 0.6389
# Batch Number 521, Loss: 0.3120
# Batch Number 522, Loss: 0.5573
# Batch Number 523, Loss: 0.3078
# Batch Number 524, Loss: 0.5711
# Batch Number 525, Loss: 0.5293
# Batch Number 526, Loss: 0.2013
# Batch Number 527, Loss: 0.3196
# Batch Number 528, Loss: 0.1870
# Batch Number 529, Loss: 0.2237
# Batch Number 530, Loss: 0.2390
# Batch Number 531, Loss: 0.6083
# Batch Number 532, Loss: 0.2174
# Batch Number 533, Loss: 0.2415
# Batch Number 534, Loss: 0.4386
# Batch Number 535, Loss: 0.2472
# Batch Number 536, Loss: 0.3897
# Batch Number 537, Loss: 0.4873
# Batch Number 538, Loss: 0.4966
# Batch Number 539, Loss: 0.1496
# Batch Number 540, Loss: 0.3740
# Batch Number 541, Loss: 0.4445
# Batch Number 542, Loss: 0.3559
# Batch Number 543, Loss: 0.4428
# Batch Number 544, Loss: 0.3002
# Batch Number 545, Loss: 0.6135
# Batch Number 546, Loss: 0.5337
# Batch Number 547, Loss: 0.5119
# Batch Number 548, Loss: 0.5995
# Batch Number 549, Loss: 0.5623
# Batch Number 550, Loss: 0.2016
# Batch Number 551, Loss: 0.1570
# Batch Number 552, Loss: 0.3492
# Batch Number 553, Loss: 0.3310
# Batch Number 554, Loss: 0.5881
# Batch Number 555, Loss: 0.6797
# Batch Number 556, Loss: 0.1948
# Batch Number 557, Loss: 0.4630
# Batch Number 558, Loss: 0.3924
# Batch Number 559, Loss: 0.7195
# Batch Number 560, Loss: 0.2790
# Batch Number 561, Loss: 0.7130
# Batch Number 562, Loss: 0.3528
# Batch Number 563, Loss: 0.7534
# Batch Number 564, Loss: 0.7557
# Batch Number 565, Loss: 0.3873
# Batch Number 566, Loss: 0.1170
# Batch Number 567, Loss: 0.3565
# Batch Number 568, Loss: 0.3400
# Batch Number 569, Loss: 0.5015
# Batch Number 570, Loss: 0.0642
# Batch Number 571, Loss: 0.3136
# Batch Number 572, Loss: 0.3083
# Batch Number 573, Loss: 0.4946
# Batch Number 574, Loss: 0.8438
# Batch Number 575, Loss: 0.5054
# Batch Number 576, Loss: 0.4652
# Batch Number 577, Loss: 0.1606
# Batch Number 578, Loss: 0.9640
# Batch Number 579, Loss: 0.2365
# Batch Number 580, Loss: 0.4526
# Batch Number 581, Loss: 0.5507
# Batch Number 582, Loss: 0.2160
# Batch Number 583, Loss: 1.2993
# Batch Number 584, Loss: 0.4128
# Batch Number 585, Loss: 0.3168
# Batch Number 586, Loss: 0.6607
# Batch Number 587, Loss: 0.3237
# Batch Number 588, Loss: 0.3799
# Batch Number 589, Loss: 0.0770
# Batch Number 590, Loss: 0.5385
# Batch Number 591, Loss: 0.1127
# Batch Number 592, Loss: 0.4268
# Batch Number 593, Loss: 0.6259
# Batch Number 594, Loss: 0.3393
# Batch Number 595, Loss: 0.3071
# Batch Number 596, Loss: 0.3815
# Batch Number 597, Loss: 0.3572
# Batch Number 598, Loss: 0.0778
# Batch Number 599, Loss: 0.8020
# Batch Number 600, Loss: 0.3390
# Batch Number 601, Loss: 0.2149
# Batch Number 602, Loss: 0.4905
# Batch Number 603, Loss: 0.5110
# Batch Number 604, Loss: 0.4221
# Batch Number 605, Loss: 0.5711
# Batch Number 606, Loss: 0.5823
# Batch Number 607, Loss: 0.6172
# Batch Number 608, Loss: 0.2781
# Batch Number 609, Loss: 0.4359
# Batch Number 610, Loss: 0.6369
# Batch Number 611, Loss: 0.2052
# Batch Number 612, Loss: 0.5019
# Batch Number 613, Loss: 0.1574
# Batch Number 614, Loss: 0.2211
# Batch Number 615, Loss: 0.5022
# Batch Number 616, Loss: 0.2450
# Batch Number 617, Loss: 0.4986
# Batch Number 618, Loss: 0.4133
# Batch Number 619, Loss: 0.4333
# Batch Number 620, Loss: 0.3012
# Batch Number 621, Loss: 0.3601
# Batch Number 622, Loss: 0.1562
# Batch Number 623, Loss: 0.2980
# Batch Number 624, Loss: 0.2269
# Batch Number 625, Loss: 0.4808
# Batch Number 626, Loss: 0.0234
# Batch Number 627, Loss: 0.2570
# Batch Number 628, Loss: 0.3209
# Batch Number 629, Loss: 0.4724
# Batch Number 630, Loss: 0.0949
# Batch Number 631, Loss: 0.3086
# Batch Number 632, Loss: 0.1908
# Batch Number 633, Loss: 0.4219
# Batch Number 634, Loss: 0.4310
# Batch Number 635, Loss: 0.8031
# Batch Number 636, Loss: 0.6367
# Batch Number 637, Loss: 0.4044
# Batch Number 638, Loss: 0.6393
# Batch Number 639, Loss: 1.0541
# Batch Number 640, Loss: 0.2636
# Batch Number 641, Loss: 0.4075
# Batch Number 642, Loss: 0.2788
# Batch Number 643, Loss: 0.8409
# Batch Number 644, Loss: 0.2450
# Batch Number 645, Loss: 0.2145
# Batch Number 646, Loss: 0.6202
# Batch Number 647, Loss: 0.1149
# Batch Number 648, Loss: 0.3495
# Batch Number 649, Loss: 0.5798
# Batch Number 650, Loss: 0.2167
# Batch Number 651, Loss: 0.3611
# Batch Number 652, Loss: 0.4977
# Batch Number 653, Loss: 0.0307
# Batch Number 654, Loss: 0.6288
# Batch Number 655, Loss: 0.5974
# Batch Number 656, Loss: 0.1815
# Batch Number 657, Loss: 0.1702
# Batch Number 658, Loss: 0.1282
# Batch Number 659, Loss: 0.7692
# Batch Number 660, Loss: 0.1967
# Batch Number 661, Loss: 0.1630
# Batch Number 662, Loss: 0.3856
# Batch Number 663, Loss: 0.5473
# Batch Number 664, Loss: 0.3761
# Batch Number 665, Loss: 0.5500
# Batch Number 666, Loss: 0.3215
# Batch Number 667, Loss: 0.5566
# Batch Number 668, Loss: 0.4524
# Batch Number 669, Loss: 0.4594
# Batch Number 670, Loss: 0.2285
# Batch Number 671, Loss: 0.4874
# Batch Number 672, Loss: 0.3713
# Batch Number 673, Loss: 0.2907
# Batch Number 674, Loss: 0.5142
# Batch Number 675, Loss: 0.1436
# Batch Number 676, Loss: 0.0704
# Batch Number 677, Loss: 0.3133
# Batch Number 678, Loss: 0.2641
# Batch Number 679, Loss: 0.2122
# Batch Number 680, Loss: 0.0700
# Batch Number 681, Loss: 0.3046
# Batch Number 682, Loss: 0.5936
# Batch Number 683, Loss: 0.3082
# Batch Number 684, Loss: 0.3332
# Batch Number 685, Loss: 0.2008
# Batch Number 686, Loss: 0.3000
# Batch Number 687, Loss: 0.5215
# Batch Number 688, Loss: 0.0082
# Batch Number 689, Loss: 0.4111
# Batch Number 690, Loss: 0.2910
# Batch Number 691, Loss: 0.4191
# Batch Number 692, Loss: 0.4651
# Batch Number 693, Loss: 1.2679
# Batch Number 694, Loss: 0.2668
# Batch Number 695, Loss: 0.1358
# Batch Number 696, Loss: 0.3203
# Batch Number 697, Loss: 0.0976
# Batch Number 698, Loss: 0.2730
# Batch Number 699, Loss: 0.1966
# Batch Number 700, Loss: 0.1542
# Batch Number 701, Loss: 0.5392
# Batch Number 702, Loss: 0.1616
# Batch Number 703, Loss: 0.5691
# Batch Number 704, Loss: 0.9918
# Batch Number 705, Loss: 0.4779
# Batch Number 706, Loss: 0.8995
# Batch Number 707, Loss: 0.9296
# Batch Number 708, Loss: 0.4577
# Batch Number 709, Loss: 0.4343
# Batch Number 710, Loss: 0.3096
# Batch Number 711, Loss: 0.0681
# Batch Number 712, Loss: 0.3236
# Batch Number 713, Loss: 0.2838
# Batch Number 714, Loss: 0.6479
# Batch Number 715, Loss: 0.3791
# Batch Number 716, Loss: 0.2525
# Batch Number 717, Loss: 0.7616
# Batch Number 718, Loss: 0.7359
# Batch Number 719, Loss: 0.1068
# Batch Number 720, Loss: 0.3419
# Batch Number 721, Loss: 0.3556
# Batch Number 722, Loss: 0.0809
# Batch Number 723, Loss: 0.1169
# Batch Number 724, Loss: 0.1954
# Batch Number 725, Loss: 0.7505
# Batch Number 726, Loss: 0.1511
# Batch Number 727, Loss: 0.7408
# Batch Number 728, Loss: 0.4393
# Batch Number 729, Loss: 0.4885
# Batch Number 730, Loss: 0.9232
# Batch Number 731, Loss: 0.1302
# Batch Number 732, Loss: 0.2580
# Batch Number 733, Loss: 0.3327
# Batch Number 734, Loss: 0.6198
# Batch Number 735, Loss: 0.7752
# Batch Number 736, Loss: 0.1597
# Batch Number 737, Loss: 0.2481
# Batch Number 738, Loss: 0.9024
# Batch Number 739, Loss: 1.0089
# Batch Number 740, Loss: 0.5052
# Batch Number 741, Loss: 0.2913
# Batch Number 742, Loss: 0.2748
# Batch Number 743, Loss: 0.0629
# Batch Number 744, Loss: 0.1950
# Batch Number 745, Loss: 0.2414
# Batch Number 746, Loss: 0.7097
# Batch Number 747, Loss: 0.5101
# Batch Number 748, Loss: 0.4864
# Batch Number 749, Loss: 0.6789
# Batch Number 750, Loss: 0.1382
# Batch Number 751, Loss: 0.1900
# Batch Number 752, Loss: 0.2841
# Batch Number 753, Loss: 0.5663
# Batch Number 754, Loss: 0.1986
# Batch Number 755, Loss: 0.0352
# Batch Number 756, Loss: 0.4076
# Batch Number 757, Loss: 0.2399
# Batch Number 758, Loss: 0.8519
# Batch Number 759, Loss: 0.5540
# Batch Number 760, Loss: 0.7910
# Batch Number 761, Loss: 0.3024
# Batch Number 762, Loss: 0.3341
# Batch Number 763, Loss: 0.2350
# Batch Number 764, Loss: 0.3913
# Batch Number 765, Loss: 0.5972
# Batch Number 766, Loss: 0.3700
# Batch Number 767, Loss: 0.4352
# Batch Number 768, Loss: 0.6118
# Batch Number 769, Loss: 0.3675
# Batch Number 770, Loss: 0.2104
# Batch Number 771, Loss: 0.3752
# Batch Number 772, Loss: 0.1916
# Batch Number 773, Loss: 0.3584
# Batch Number 774, Loss: 0.1559
# Batch Number 775, Loss: 0.4305
# Batch Number 776, Loss: 0.3277
# Batch Number 777, Loss: 0.3486
# Batch Number 778, Loss: 0.3277
# Batch Number 779, Loss: 0.6106
# Batch Number 780, Loss: 0.4294
# Batch Number 781, Loss: 0.0848
# Batch Number 782, Loss: 0.4416
# Batch Number 783, Loss: 0.5458
# Batch Number 784, Loss: 0.5421
# Batch Number 785, Loss: 0.1780
# Batch Number 786, Loss: 0.2276
# Batch Number 787, Loss: 0.7297
# Batch Number 788, Loss: 0.5601
# Batch Number 789, Loss: 0.5530
# Batch Number 790, Loss: 0.1129
# Batch Number 791, Loss: 0.1621
# Batch Number 792, Loss: 0.1797
# Batch Number 793, Loss: 0.1500
# Batch Number 794, Loss: 0.4488
# Batch Number 795, Loss: 0.1581
# Batch Number 796, Loss: 0.7323
# Batch Number 797, Loss: 0.3294
# Batch Number 798, Loss: 0.2379
# Batch Number 799, Loss: 0.1856
# Batch Number 800, Loss: 0.2340
# Batch Number 801, Loss: 0.2290
# Batch Number 802, Loss: 0.1977
# Batch Number 803, Loss: 0.3485
# Batch Number 804, Loss: 0.4212
# Batch Number 805, Loss: 0.5456
# Batch Number 806, Loss: 0.2662
# Batch Number 807, Loss: 0.5432
# Batch Number 808, Loss: 0.5431
# Batch Number 809, Loss: 0.4835
# Batch Number 810, Loss: 0.2918
# Batch Number 811, Loss: 0.9722
# Batch Number 812, Loss: 0.4249
# Batch Number 813, Loss: 0.4222
# Batch Number 814, Loss: 0.1159
# Batch Number 815, Loss: 0.2656
# Batch Number 816, Loss: 0.4642
# Batch Number 817, Loss: 0.3188
# Batch Number 818, Loss: 0.4605
# Batch Number 819, Loss: 0.3153
# Batch Number 820, Loss: 0.1827
# Batch Number 821, Loss: 0.3501
# Batch Number 822, Loss: 0.2199
# Batch Number 823, Loss: 0.5411
# Batch Number 824, Loss: 0.3773
# Batch Number 825, Loss: 0.3450
# Batch Number 826, Loss: 0.2483
# Batch Number 827, Loss: 0.4471
# Batch Number 828, Loss: 0.3804
# Batch Number 829, Loss: 0.2539
# Batch Number 830, Loss: 0.1500
# Batch Number 831, Loss: 0.3133
# Batch Number 832, Loss: 0.2101
# Batch Number 833, Loss: 0.9994
# Batch Number 834, Loss: 0.1728
# Batch Number 835, Loss: 0.2869
# Batch Number 836, Loss: 0.3728
# Batch Number 837, Loss: 0.2618
# Batch Number 838, Loss: 0.6207
# Batch Number 839, Loss: 0.2473
# Batch Number 840, Loss: 0.2946
# Batch Number 841, Loss: 0.3040
# Batch Number 842, Loss: 0.2596
# Batch Number 843, Loss: 0.5180
# Batch Number 844, Loss: 0.1965
# Batch Number 845, Loss: 0.0834
# Batch Number 846, Loss: 0.4431
# Batch Number 847, Loss: 0.0730
# Batch Number 848, Loss: 0.2599
# Batch Number 849, Loss: 0.3980
# Batch Number 850, Loss: 0.4868
# Batch Number 851, Loss: 0.6681
# Batch Number 852, Loss: 0.1899
# Batch Number 853, Loss: 0.5050
# Batch Number 854, Loss: 0.5203
# Batch Number 855, Loss: 0.1786
# Batch Number 856, Loss: 0.9078
# Batch Number 857, Loss: 0.2480
# Batch Number 858, Loss: 0.1432
# Batch Number 859, Loss: 0.4403
# Batch Number 860, Loss: 0.3546
# Batch Number 861, Loss: 0.7292
# Batch Number 862, Loss: 0.4077
# Batch Number 863, Loss: 0.3200
# Batch Number 864, Loss: 0.3178
# Batch Number 865, Loss: 0.4444
# Batch Number 866, Loss: 0.3321
# Batch Number 867, Loss: 0.7142
# Batch Number 868, Loss: 0.4024
# Batch Number 869, Loss: 0.1898
# Batch Number 870, Loss: 0.3218
# Batch Number 871, Loss: 0.2429
# Batch Number 872, Loss: 0.3130
# Batch Number 873, Loss: 0.0382
# Batch Number 874, Loss: 0.2067
# Batch Number 875, Loss: 0.4169
# Batch Number 876, Loss: 0.6446
# Batch Number 877, Loss: 0.1596
# Batch Number 878, Loss: 0.7211
# Batch Number 879, Loss: 0.6896
# Batch Number 880, Loss: 0.1128
# Batch Number 881, Loss: 0.3785
# Batch Number 882, Loss: 0.1912
# Batch Number 883, Loss: 0.2702
# Batch Number 884, Loss: 0.4275
# Batch Number 885, Loss: 0.3606
# Batch Number 886, Loss: 0.5006
# Batch Number 887, Loss: 0.5561
# Batch Number 888, Loss: 0.7945
# Batch Number 889, Loss: 0.4911
# Batch Number 890, Loss: 0.2989
# Batch Number 891, Loss: 0.6125
# Batch Number 892, Loss: 0.2912
# Batch Number 893, Loss: 0.4157
# Batch Number 894, Loss: 0.5852
# Batch Number 895, Loss: 0.5836
# Batch Number 896, Loss: 0.5970
# Batch Number 897, Loss: 0.3903
# Batch Number 898, Loss: 0.3066
# Batch Number 899, Loss: 0.3267
# Batch Number 900, Loss: 0.3060
# Batch Number 901, Loss: 0.4581
# Batch Number 902, Loss: 0.4312
# Batch Number 903, Loss: 0.4094
# Batch Number 904, Loss: 0.7484
# Batch Number 905, Loss: 0.0510
# Batch Number 906, Loss: 0.2593
# Batch Number 907, Loss: 0.3146
# Batch Number 908, Loss: 0.1712
# Batch Number 909, Loss: 0.2776
# Batch Number 910, Loss: 0.7701
# Batch Number 911, Loss: 0.1832
# Batch Number 912, Loss: 0.3075
# Batch Number 913, Loss: 0.0909
# Batch Number 914, Loss: 0.1298
# Batch Number 915, Loss: 0.7371
# Batch Number 916, Loss: 0.2085
# Batch Number 917, Loss: 0.3526
# Batch Number 918, Loss: 0.5760
# Batch Number 919, Loss: 0.1613
# Batch Number 920, Loss: 0.1217
# Batch Number 921, Loss: 0.1392
# Batch Number 922, Loss: 0.3017
# Batch Number 923, Loss: 0.5657
# Batch Number 924, Loss: 0.1990
# Batch Number 925, Loss: 0.3913
# Batch Number 926, Loss: 1.1417
# Batch Number 927, Loss: 0.2787
# Batch Number 928, Loss: 0.1644
# Batch Number 929, Loss: 0.2253
# Batch Number 930, Loss: 1.0346
# Batch Number 931, Loss: 0.0880
# Batch Number 932, Loss: 0.4873
# Batch Number 933, Loss: 0.4066
# Batch Number 934, Loss: 0.1496
# Batch Number 935, Loss: 0.6106
# Batch Number 936, Loss: 0.1951
# Batch Number 937, Loss: 0.3682
# Batch Number 938, Loss: 0.0216

# %%
# The testing loop

correct = 0
total = 0

with torch.no_grad():
    for images, labels in test_loader:
        images = images.view(images.shape[0], -1)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        # print(" Predicted  ",predicted)
        # print("True Labels ", labels)

print('Accuracy: {:.2f}%'.format(100 * correct / total))
# Out:
# Accuracy: 93.27%

# %%
print(" Predicted  ",predicted)
print("True Labels ", labels)
# Out:
#  Predicted   tensor([7, 1, 1, 3, 8, 9, 8, 7, 7, 8, 1, 5, 9, 5, 6, 0])
# True Labels  tensor([7, 1, 1, 3, 8, 8, 8, 7, 7, 8, 1, 5, 9, 5, 5, 0])

# %%
# Plot some weight evolution
plt.figure(figsize=(40, 20))
plt.grid()
plt.title("Example 1 of weight evolution (in first FC layer)")
plt.plot(weight_evolution_list_1, marker='o')
plt.show()

# %%
plt.figure(figsize=(40, 20))
plt.grid()
plt.title("Example 2 of weight evolution (in first FC layer)")
plt.plot(weight_evolution_list_2, marker='o')
plt.show()

# %%
plt.figure(figsize=(40, 20))
plt.grid()
plt.title("Example 4 of weight evolution (in second FC layer)")
plt.plot(weight_evolution_list_4, marker='o')
plt.show()

# %%
plt.figure(figsize=(40, 20))
plt.grid()
plt.title("Example 5 of weight evolution (in second FC layer)")
plt.plot(weight_evolution_list_5, marker='o')
plt.show()

# %%
print(len(weight_evolution_list_1))
# Out:
# 938
